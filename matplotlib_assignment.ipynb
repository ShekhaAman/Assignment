# %%
import csv
import pandas as pd

# %%
#1)
url="https://raw.githubusercontent.com/Geoyi/Cleaning-Titanic-Data/master/titanic_original.csv"
df=pd.read_csv(url)
df
# Out:
#       pclass  survived                                             name  \
# 0        1.0       1.0                    Allen, Miss. Elisabeth Walton
# 1        1.0       1.0                   Allison, Master. Hudson Trevor
# 2        1.0       0.0                     Allison, Miss. Helen Loraine
# 3        1.0       0.0             Allison, Mr. Hudson Joshua Creighton
# 4        1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1305     3.0       0.0                            Zabour, Miss. Thamine
# 1306     3.0       0.0                        Zakarian, Mr. Mapriededer
# 1307     3.0       0.0                              Zakarian, Mr. Ortin
# 1308     3.0       0.0                               Zimmerman, Mr. Leo
# 1309     NaN       NaN                                              NaN
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
df['sex'].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='sex'>

# %%
#2 
df['sex'] = df['sex'].replace({'male':1, 'female':0})

# %%
df.plot.scatter(x='fare',y='age',c='sex')
# Out:
# <AxesSubplot:xlabel='fare', ylabel='age'>

# %%
df
# Out:
#       pclass  survived                                             name  sex  \
# 0        1.0       1.0                    Allen, Miss. Elisabeth Walton  0.0
# 1        1.0       1.0                   Allison, Master. Hudson Trevor  1.0
# 2        1.0       0.0                     Allison, Miss. Helen Loraine  0.0
# 3        1.0       0.0             Allison, Mr. Hudson Joshua Creighton  1.0
# 4        1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  0.0
# ...      ...       ...                                              ...  ...
# 1305     3.0       0.0                            Zabour, Miss. Thamine  0.0
# 1306     3.0       0.0                        Zakarian, Mr. Mapriededer  1.0
# 1307     3.0       0.0                              Zakarian, Mr. Ortin  1.0
# 1308     3.0       0.0                               Zimmerman, Mr. Leo  1.0
# 1309     NaN       NaN                                              NaN  NaN
#
# ...
